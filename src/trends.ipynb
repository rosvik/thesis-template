# %% [markdown]
# https://trends.google.com/trends/explore?date=2015-11-09%202020-11-19&q=%2Fg%2F11bwp1s2k3,%2Fg%2F11gd3905v1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
from qbstyles import mpl_style

mpl_style(dark=False, minor_ticks=False)

data = pd.read_csv("data/trends.csv")

data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

data = data.sort_values('Date').set_index('Date')

data
# Out:
#             Netflix  Disney+
# Date
# 2017-10-15       38        0
# 2017-10-22       39        0
# 2017-10-29       42        0
# 2017-11-05       39        0
# 2017-11-12       37        0
# ...             ...      ...
# 2022-09-04       46       10
# 2022-09-11       46       10
# 2022-09-18       49        9
# 2022-09-25       56       10
# 2022-10-02       51       10
#
# [260 rows x 2 columns]

# %%
ax = data.plot(kind='line', figsize=(12,6))

plt.xlabel('Time');
plt.ylabel('Interest');
plt.savefig("../assets/trends.pdf")
